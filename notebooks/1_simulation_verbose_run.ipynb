# %%
import random
import sys, os
sys.path.insert(0, os.path.abspath(".."))

import simulation_engine as engine

# %matplotlib inline
# %load_ext autoreload
# %autoreload 2

# %% [markdown]
# # Simulation 1 — Single Verbose Run
#
# This simulation runs a single 6-player game with verbose logging enabled. The purpose is twofold: to verify that the engine runs correctly end-to-end, and to provide a readable trace of one complete game that illustrates how the round loop, agent decisions, and card draws interact in practice.
#
# A fixed random seed is used so the output is stable and reproducible.

# %%
random.seed(0)
record = engine.run_game(player_count = 6, verbose = True)
# Out:
# Characters: ['gatherer', 'craftsman', 'builder', 'cook', 'sailor', 'fire_starter']
# Boat parts required: 4
# Active missions: ['build_a_shelter', 'cut_the_keel', 'gather_materials']
#
# Round  1 | mission: build_a_shelter              | volcano left: 11 (used 0) | boat: 0/4 | scores: [4, 4, 4, 4, 0, 0] (+[4, 4, 4, 4, 0, 0])
# Round  2 | mission: —                            | volcano left: 10 (used 1) | boat: 0/4 | scores: [0, 0, 4, 4, 4, 4] (+[-4, -4, 0, 0, 4, 4])
# Round  3 | mission: —                            | volcano left:  9 (used 1) | boat: 0/4 | scores: [4, 4, 4, 4, 0, 0] (+[4, 4, 0, 0, -4, -4])
# Round  4 | mission: —                            | volcano left:  8 (used 1) | boat: 0/4 | scores: [4, 4, 4, 4, 0, 0] (+[0, 0, 0, 0, 0, 0])
# Round  5 | mission: torch_for_the_night          | volcano left:  8 (used 0) | boat: 0/4 | scores: [7, 7, 0, 0, 7, 4] (+[3, 3, -4, -4, 7, 4])
# Round  6 | mission: cut_the_keel                 | volcano left:  8 (used 0) | boat: 1/4 | scores: [1, 7, 1, 7, 7, 5] (+[-6, 0, 1, 7, 0, 1])
# Round  7 | mission: assemble_the_hull            | volcano left:  8 (used 0) | boat: 2/4 | scores: [8, 1, 8, 8, 1, 5] (+[7, -6, 7, 1, -6, 0])
# Round  8 | mission: gather_materials             | volcano left:  8 (used 0) | boat: 2/4 | scores: [8, 7, 3, 8, 3, 8] (+[0, 6, -5, 0, 2, 3])
# Round  9 | mission: light_a_fire                 | volcano left:  8 (used 0) | boat: 2/4 | scores: [10, 3, 8, 3, 7, 10] (+[2, -4, 5, -5, 4, 2])
# Round 10 | mission: —                            | volcano left:  7 (used 1) | boat: 2/4 | scores: [10, 3, 7, 9, 3, 10] (+[0, 0, -1, 6, -4, 0])
# Round 11 | mission: —                            | volcano left:  6 (used 1) | boat: 2/4 | scores: [10, 10, 3, 7, 9, 3] (+[0, 7, -4, -2, 6, -7])
# Round 12 | mission: —                            | volcano left:  5 (used 1) | boat: 2/4 | scores: [10, 10, 9, 7, 3, 3] (+[0, 0, 6, 0, -6, 0])
# Round 13 | mission: —                            | volcano left:  4 (used 1) | boat: 2/4 | scores: [10, 7, 9, 3, 3, 10] (+[0, -3, 0, -4, 0, 7])
# Round 14 | mission: make_the_sail                | volcano left:  4 (used 0) | boat: 3/4 | scores: [3, 4, 9, 8, 10, 10] (+[-7, -3, 0, 5, 7, 0])
# Round 15 | mission: hunt                         | volcano left:  4 (used 0) | boat: 3/4 | scores: [12, 6, 4, 13, 8, 10] (+[9, 2, -5, 5, -2, 0])
# Round 16 | mission: prepare_food                 | volcano left:  4 (used 0) | boat: 3/4 | scores: [13, 12, 6, 11, 13, 7] (+[1, 6, 2, -2, 5, -3])
# Round 17 | mission: raise_the_mast               | volcano left:  4 (used 0) | boat: 4/4 | scores: [8, 15, 7, 12, 15, 11] (+[-5, 3, 1, 1, 2, 4])
#
# Outcome: WIN after 17 rounds
# Final scores: {'fire_starter': 8, 'cook': 15, 'sailor': 7, 'craftsman': 12, 'builder': 15, 'gatherer': 11}
# Boat parts built: 4/4
# Volcano cards remaining: 4
# Resources consumed: {'wood': 13, 'rope': 18, 'stone': 10}
# Mission failures by resource: {'rope': 2, 'wood': 1}  (any_extra: 0, tool_damaged: {})
# Tool repairs: {'vessel': 1}

# %%
print("── Game Record ─────────────────────────────────────")
print(f"Outcome:                  {record.outcome.upper()}")
print(f"Players:                  {record.player_count}")
print(f"Characters:               {[c.value for c in record.characters]}")
print(f"Rounds played:            {record.rounds_played}")
print(f"Boat parts built:         {record.boat_parts_built} / {record.boat_parts_required}")
print(f"Volcano cards remaining:  {record.volcano_cards_remaining}")
print(f"Final scores:             { {c.value: s for c, s in record.final_scores.items()} }")
# Out:
# ── Game Record ─────────────────────────────────────
# Outcome:                  WIN
# Players:                  6
# Characters:               ['fire_starter', 'cook', 'sailor', 'craftsman', 'builder', 'gatherer']
# Rounds played:            17
# Boat parts built:         4 / 4
# Volcano cards remaining:  4
# Final scores:             {'fire_starter': 8, 'cook': 15, 'sailor': 7, 'craftsman': 12, 'builder': 15, 'gatherer': 11}

# %% [markdown]
# #### Reading the Verbose Trace
#
# Each row in the trace above represents one round:
#
# - **`Round N`** — round number
# - **`mission: <name>`** — the mission completed this round; `—` means the round ended without a completion (mission failed or no eligible mission due to Panic)
# - **`volcano left: N (used M)`** — cards remaining in the volcano deck and how many were consumed this round (0 on a success, 1 on a failure or special card effect)
# - **`boat: X/Y`** — boat parts built so far vs. the number required to win
# - **`scores: [...] (+[...])`** — each player's cumulative score and the points gained this round (negative values indicate a Smoke penalty was applied)
